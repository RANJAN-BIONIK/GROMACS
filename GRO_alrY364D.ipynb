# %% [markdown]
# files to add in folder : (step3_input.pdb) (production.xtc) (production.cpt) (IE.mdp)  (alrY364DNPT_equilibration.gro)  (alrY364DNPT_equilibration.cpt)

# %%
# upgrade cmake; required for GROMACS 2021 or higher version
# !pip install cmake --upgrade

#Installing py3Dmol using pip
# !pip install py3Dmol

#Importing py3Dmol for safety
import py3Dmol

#Installing biopython using pip
# !pip install biopython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 17.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cmake
#     Found existing installation: cmake 3.27.9
#     Uninstalling cmake-3.27.9:
#       Successfully uninstalled cmake-3.27.9
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.1 MB/s eta 0:00:00
# ...

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MD/alrY364D
# !pwd
# Out:
# /content/drive/MyDrive/MD/alrY364D
# /content/drive/MyDrive/MD/alrY364D

# %%
# access permission and check if gromacs works
# %%bash
chmod +x "/content/drive/MyDrive/gmx/gromacs/bin/gmx"
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
gmx -h
# Out:
# SYNOPSIS
#
# gmx [-[no]h] [-[no]quiet] [-[no]version] [-[no]copyright] [-nice <int>]
#     [-[no]backup]
#
# OPTIONS
#
# Other options:
#
#  -[no]h                     (no)
#            Print help and quit
#  -[no]quiet                 (no)
#            Do not print common startup info or quotes
#  -[no]version               (no)
#            Print extended version information and quit
#  -[no]copyright             (no)
#            Print copyright information on startup
#  -nice   <int>              (19)
#            Set the nicelevel (default depends on command)
#  -[no]backup                (yes)
#            Write backups if output files exist
#
# Additional help is available on the following topics:
#     commands    List of available commands
#     selections  Selection syntax and usage
# To access the help, use 'gmx help <topic>'.
# For help on a command, use 'gmx help <command>'.
#                          :-) GROMACS - gmx, 2023.1 (-:
#
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# gmx convert-tpr -s alrY364Dstep5_production_2_2_for_10ns.tpr -extend 4000 -o alrY364Dstep5_production_2_2_for_14ns.tpr
# Out:
# Input file:
#   Run start step                                     0
#   Run start time                                     0 ps
#   Step to be made during run                   5000000
#   Runtime for the run                            10000 ps
#   Run end step                                 5000000
#   Run end time                                   10000 ps
#
# Extending remaining runtime by 4000 ps
#
# Output file:
#   Run start step                                     0
#   Run start time                                     0 ps
#   Step to be made during run                   7000000
#   Runtime for the run                            14000 ps
#   Run end step                                 7000000
#   Run end time                                   14000 ps
#                    :-) GROMACS - gmx convert-tpr, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# gmx mdrun -deffnm alrY364Dstep5_production_2_2_for_14ns -cpi alrY364Dstep5_production_2_2_for_10ns.cpt -noappend -nb gpu -ntmpi 10
# Out:
# Process is terminated.

# %% [markdown]
# fgcghchgvh

# %%
# fhfyfthdrdyt

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# gmx trjcat -f alrY364D_6ns.xtc alrY364Dstep5_production_2_2_for_10ns.part0003.xtc -o alrY364D_10ns.xtc

# %%
### vfgdvfhsdvfhsdg

# %% [markdown]
# bdfhvbfhdvbfhjvbdfhvhjkb

# %%
##########

# %%
#### dbchsdbvhjsfbv

# %% [markdown]
# Analysis

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo -e '"Protein" | "UNK" \n q' |gmx make_ndx -f step3_input.pdb  -o alrY364D_PROTEIN_UNK.ndx
# Out:
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   744    Protein residues
# There are: 47065      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 151779 atoms
#   1 Protein             : 11104 atoms
#   2 Protein-H           :  5530 atoms
#   3 C-alpha             :   744 atoms
#   4 Backbone            :  2232 atoms
#   5 MainChain           :  2974 atoms
#   6 MainChain+Cb        :  3640 atoms
#   7 MainChain+H         :  3676 atoms
#   8 SideChain           :  7428 atoms
#   9 SideChain-H         :  2556 atoms
#  10 Prot-Masses         : 11104 atoms
#  11 non-Protein         : 140675 atoms
#  12 Other               : 140675 atoms
#  13 UNK                 :    37 atoms
#  14 POT                 :   145 atoms
#  15 CLA                 :   132 atoms
#  16 TIP3                : 140361 atoms
#
# ...

# %%
## should be changeed evrytime accoridng to the PDB file atom nunber of  PROA and PROB start and end atoms
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo -e '1 & a 1-5552 \n q' |gmx make_ndx -f step3_input.pdb  -o alrY364D_index_for_chain_A.ndx
# Out:
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   744    Protein residues
# There are: 47065      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 151779 atoms
#   1 Protein             : 11104 atoms
#   2 Protein-H           :  5530 atoms
#   3 C-alpha             :   744 atoms
#   4 Backbone            :  2232 atoms
#   5 MainChain           :  2974 atoms
#   6 MainChain+Cb        :  3640 atoms
#   7 MainChain+H         :  3676 atoms
#   8 SideChain           :  7428 atoms
#   9 SideChain-H         :  2556 atoms
#  10 Prot-Masses         : 11104 atoms
#  11 non-Protein         : 140675 atoms
#  12 Other               : 140675 atoms
#  13 UNK                 :    37 atoms
#  14 POT                 :   145 atoms
#  15 CLA                 :   132 atoms
#  16 TIP3                : 140361 atoms
#
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo -e '1 & a 5553-11104 \n q' |gmx make_ndx -f step3_input.pdb  -o alrY364D_index_for_chain_B.ndx
# Out:
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   744    Protein residues
# There are: 47065      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 151779 atoms
#   1 Protein             : 11104 atoms
#   2 Protein-H           :  5530 atoms
#   3 C-alpha             :   744 atoms
#   4 Backbone            :  2232 atoms
#   5 MainChain           :  2974 atoms
#   6 MainChain+Cb        :  3640 atoms
#   7 MainChain+H         :  3676 atoms
#   8 SideChain           :  7428 atoms
#   9 SideChain-H         :  2556 atoms
#  10 Prot-Masses         : 11104 atoms
#  11 non-Protein         : 140675 atoms
#  12 Other               : 140675 atoms
#  13 UNK                 :    37 atoms
#  14 POT                 :   145 atoms
#  15 CLA                 :   132 atoms
#  16 TIP3                : 140361 atoms
#
# ...

# %%
import os

def merge_files(file_names, output_file_name):
    try:
        with open(output_file_name, 'w') as output_file:
            for file_name in file_names:
                with open(file_name, 'r') as input_file:
                    output_file.write(input_file.read())
                    output_file.write('\n')  # Add a newline after each file's content
        print("Files merged successfully!")
    except FileNotFoundError as e:
        print(f"Error: {e.filename} not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# List the filenames of the four files you want to merge
file_names = ['index.ndx', 'alrY364D_PROTEIN_UNK.ndx', 'alrY364D_index_for_chain_A.ndx', 'alrY364D_index_for_chain_B.ndx']
output_file_name = 'alrY364D_merged_index.ndx'

merge_files(file_names, output_file_name)
# Out:
# Files merged successfully!

# %%
## The root mean square deviation (RMSD) is a practical parameter to compare the
## backbones of a protein from its initial to final state, which illustrates
## the dynamics of structure during the simulation.
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 4 4 | gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_whole.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_whole.xvg
# Out:
# Selected 4: 'Backbone'
# Selected 4: 'Backbone'
#                        :-) GROMACS - gmx rms, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_whole.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_whole.xvg
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Select group for least squares fit
# Group     0 (         System) has 151779 elements
# Group     1 (        Protein) has 11104 elements
# Group     2 (      Protein-H) has  5530 elements
# Group     3 (        C-alpha) has   744 elements
# Group     4 (       Backbone) has  2232 elements
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo 16  | gmx msd -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_MSD_UNK.xvg -xvg xmgrace -mol alrY364D_MSD_UNK_RES.xvg -n alrY364D_merged_index.ndx
# echo 4  | gmx msd -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_MSD_PRO.xvg -xvg xmgrace -mol alrY364D_MSD_PRO_RES.xvg -n alrY364D_merged_index.ndx
# Out:
#                        :-) GROMACS - gmx msd, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx msd -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_MSD_UNK.xvg -xvg xmgrace -mol alrY364D_MSD_UNK_RES.xvg -n alrY364D_merged_index.ndx
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Last frame      10000 time 10000.000
# Analyzed 10001 frames, last time 10000.000
#
# GROMACS reminds you: "I Have a Bad Case Of Purple Diarrhea" (Urban Dance Squad)
#
#                        :-) GROMACS - gmx msd, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# ...

# %%
## The root mean square deviation (RMSD) is a practical parameter to compare the
## backbones of a protein from its initial to final state, which illustrates
## the dynamics of structure during the simulation. only for the ligand
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 4 13 | gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_BACK_UNK.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_BACK_UNK.xvg
# Out:
# Selected 4: 'Backbone'
# Selected 13: 'UNK'
#                        :-) GROMACS - gmx rms, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_BACK_UNK.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_BACK_UNK.xvg
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Select group for least squares fit
# Group     0 (         System) has 151779 elements
# Group     1 (        Protein) has 11104 elements
# Group     2 (      Protein-H) has  5530 elements
# Group     3 (        C-alpha) has   744 elements
# Group     4 (       Backbone) has  2232 elements
# ...

# %%
##RMSD OF UNK
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 13 13 | gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_UNK_UNK.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_UNK_UNK.xvg
# Out:
# Selected 13: 'UNK'
# Selected 13: 'UNK'
#                        :-) GROMACS - gmx rms, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx rms -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dproduction_rmsd_UNK_UNK.xvg -xvg xmgrace -dist alrY364Dproduction_rmsd_dist_UNK_UNK.xvg
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Select group for least squares fit
# Group     0 (         System) has 151779 elements
# Group     1 (        Protein) has 11104 elements
# Group     2 (      Protein-H) has  5530 elements
# Group     3 (        C-alpha) has   744 elements
# Group     4 (       Backbone) has  2232 elements
# ...

# %%
##check the energy
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 13| gmx energy -f alrY364Dener.edr -o alrY364Dproduction_Total_energy.xvg -xvg xmgrace
echo 6| gmx energy -f alrY364Dener.edr -o alrY364Dproduction_LJ_14.xvg -xvg xmgrace
echo 7| gmx energy -f alrY364Dener.edr -o alrY364Dproduction_Coulomb_14.xvg -xvg xmgrace
echo 8| gmx energy -f alrY364Dener.edr -o alrY364Dproduction_LJ_SR.xvg -xvg xmgrace
echo 9| gmx energy -f alrY364Dener.edr -o alrY364Dproduction_Coulomb_SR.xvg -xvg xmgrace
# Out:
#                       :-) GROMACS - gmx energy, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx energy -f alrY364Dener.edr -o alrY364Dproduction_Total_energy.xvg -xvg xmgrace
#
#
# -------------------------------------------------------
# Program:     gmx energy, version 2023.1
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File 'alrY364Dener.edr' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# ...

# %%
#sasa by ligand
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 16 | gmx sasa -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_SASA_UNK.xvg -oa alrY364D_per_atom_UNK.xvg -or alrY364D_SASA_per_res_UNK.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# ...

# %%
#sasa by chain of protein
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 38 | gmx sasa -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_chain_A_SASA.xvg -oa alrY364D_chain_A_SASA_per_atom.xvg -or alrY364D_chain_A_SASA_per_res.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
echo 56 | gmx sasa -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364D_chain_B_SASA.xvg -oa alrY364D_chain_B_SASA_per_atom.xvg -or alrY364D_chain_B_SASA_per_res.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# ...

# %%
#rmsf
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 7| gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_whole_BACK.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx
echo 16| gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx
echo 38| gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_chain_A.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx
echo 56| gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_chain_B.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx
# Out:
# Selected 7: 'Backbone'
# Selected 16: 'UNK'
# Selected 38: 'Protein_&_a_1-5552'
# Selected 56: 'Protein_&_a_5553-11104'
#                        :-) GROMACS - gmx rmsf, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_whole_BACK.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (           SOLU) has 11141 elements
# Group     1 (           SOLV) has 140638 elements
# Group     2 (         SYSTEM) has 151779 elements
# ...

# %%
#rmsf WRT resideu
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 38 | gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_chain_A_RESYES.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx -res yes
echo 56| gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_chain_B_RESYES.xvg  -xvg xmgrace -n alrY364D_merged_index.ndx -res yes
# Out:
# Selected 38: 'Protein_&_a_1-5552'
# Selected 56: 'Protein_&_a_5553-11104'
#                        :-) GROMACS - gmx rmsf, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx rmsf -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Drmsf_chain_A_RESYES.xvg -xvg xmgrace -n alrY364D_merged_index.ndx -res yes
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Select group(s) for root mean square calculation
# Group     0 (           SOLU) has 11141 elements
# Group     1 (           SOLV) has 140638 elements
# Group     2 (         SYSTEM) has 151779 elements
# Group     3 (         System) has 151779 elements
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo 38 | gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc  -o alrY364Dgyrate_chain_A.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
# echo 56 | gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc  -o alrY364Dgyrate_chain_B.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
# Out:
# Selected 38: 'Protein_&_a_1-5552'
# Selected 56: 'Protein_&_a_5553-11104'
#                       :-) GROMACS - gmx gyrate, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dgyrate_chain_A.xvg -xvg xmgrace -n alrY364D_merged_index.ndx
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Group     0 (           SOLU) has 11141 elements
# Group     1 (           SOLV) has 140638 elements
# Group     2 (         SYSTEM) has 151779 elements
# Group     3 (         System) has 151779 elements
# Group     4 (        Protein) has 11104 elements
# ...

# %%
##distance the resid is from step3_input.pdb files TYR 271 OH       UNK 0 C10 add atoom numbber accodng to PDB file
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"

gmx distance --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -select  'atomnr 9438 plus atomnr 11135' -xvg xmgrace -oall alrY364D_dis.xvg -oh alrY364D_dis_histogram.xvg
# Out:
# atomnr 9438 plus atomnr 11135:
#   Number of samples:  10001
#   Average distance:   0.66322  nm
#   Standard deviation: 0.09486  nm
#                      :-) GROMACS - gmx distance, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx distance --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -select 'atomnr 9438 plus atomnr 11135' -xvg xmgrace -oall alrY364D_dis.xvg -oh alrY364D_dis_histogram.xvg
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Last frame      10000 time 10000.000
# Analyzed 10001 frames, last time 10000.000
#
# GROMACS reminds you: "You Could Make More Money As a Butcher" (F. Zappa)

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo 1| gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc  -o alrY364Dgyrate_whole.xvg -xvg xmgrace
# Out:
# Selected 1: 'Protein'
#                       :-) GROMACS - gmx gyrate, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dgyrate_whole.xvg -xvg xmgrace
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has 151779 elements
# Group     1 (        Protein) has 11104 elements
# Group     2 (      Protein-H) has  5530 elements
# Group     3 (        C-alpha) has   744 elements
# Group     4 (       Backbone) has  2232 elements
# Group     5 (      MainChain) has  2974 elements
# Group     6 (   MainChain+Cb) has  3640 elements
# ...

# %%
# %%bash
# source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
# echo 13| gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc  -o alrY364Dgyrate_UNK.xvg -xvg xmgrace
# Out:
# Selected 13: 'UNK'
#                       :-) GROMACS - gmx gyrate, 2023.1 (-:
#
# Executable:   /content/drive/MyDrive/gmx/gromacs/bin/gmx
# Data prefix:  /content/drive/MyDrive/gmx/gromacs
# Working dir:  /content/drive/.shortcut-targets-by-id/1i9bvhUKzLP2DDWiJAKgd7wLBZV0S0Vos/MD/alrY364D
# Command line:
#   gmx gyrate --s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dgyrate_UNK.xvg -xvg xmgrace
#
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Reading file alrY364Dstep5_production_2_2_for_10ns.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has 151779 elements
# Group     1 (        Protein) has 11104 elements
# Group     2 (      Protein-H) has  5530 elements
# Group     3 (        C-alpha) has   744 elements
# Group     4 (       Backbone) has  2232 elements
# Group     5 (      MainChain) has  2974 elements
# Group     6 (   MainChain+Cb) has  3640 elements
# ...

# %%
import os
import zipfile
from google.colab import files

def zip_and_download(folder_path):
    # Get the list of files with .xvg extension in the folder
    files_to_zip = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.xvg')]

    if len(files_to_zip) == 0:
        print("No .xvg files found in the folder.")
        return

    # Create a zip file
    zip_file_name = 'alrY364D_xvg_files.zip'
    with zipfile.ZipFile(zip_file_name, 'w') as zipf:
        for file in files_to_zip:
            zipf.write(os.path.join(folder_path, file), arcname=file)

    # Download the zip file
    files.download(zip_file_name)

# Replace 'content' with the folder name you want to search for .xvg files
folder_path = '/content/drive/MyDrive/MD/alrY364D/'
zip_and_download(folder_path)

# %%
#revised minimization.mdp
# !cat /content/drive/MyDrive/MD/alrY364D/IE_.mdp

# %%
## To quantify the strength of the interaction we get The total interaction energy after this
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
gmx grompp -f IE_.mdp -c alrY364DNPT_equilibration.gro -t alrY364DNPT_equilibration.cpt -p topol.top -n alrY364D_merged_index.ndx -o alrY364D_IE.tpr
gmx mdrun -deffnm alrY364D_IE -rerun alrY364Dtraj_comp.xtc -nb cpu

# %%
##To recenter the protein and rewrap the molecules gfihvfsvbjvbkjfsnvkjsfnkjvnsfjkvnjk kjscn bhbfjvbsfkjvnskjsfknvs
## the unit cell to recover the desired shape of the box (Used for futher analysi like energy but original file is used for IE)
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 1 0 | gmx trjconv -s alrY364Dstep5_production_2_2_for_10ns.tpr -f alrY364D_10ns.xtc -o alrY364Dstep5_production_center.xtc -center -pbc mol -ur compact

# %%
## Extract the energy terms of interest via the energy module (interaction energy IE)
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
echo 2| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_UB_TOT.xvg -xvg xmgrace
echo 6| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_LJ_14_TOT.xvg -xvg xmgrace
echo 7| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_coulomb_14_TOT.xvg -xvg xmgrace
echo 21| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_coulomb_SR_PROUNK.xvg -xvg xmgrace
echo 22| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_LJ_SR_PROUNK.xvg -xvg xmgrace
echo 8| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_LJ_SR_TOT.xvg -xvg xmgrace
echo 9| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_coulomb_SR_TOT.xvg -xvg xmgrace
echo 23| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_coulomb_14_PROUNK.xvg -xvg xmgrace
echo 24| gmx energy -f alrY364D_IE.edr -o alrY364Dinteraction_energy_LJ_14_PROUNK.xvg -xvg xmgrace
